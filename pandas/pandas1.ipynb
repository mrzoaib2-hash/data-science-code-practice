# %%
import pandas as pd

# %%
s=pd.Series([12,23,45,64,23,54,64,65])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s2=pd.Series([12,23,45,64,23,54,64,65], index=["shoin","jhon","thom","nom","loppy","dp","soppy","kom"])

# %%
print(s2)
# Out:
# shoin    12
# jhon     23
# thom     45
# nom      64
# loppy    23
# dp       54
# soppy    64
# kom      65
# dtype: int64

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

# %%
df=pd.DataFrame(data)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
