# %%
import numpy as np

# %%
arr=np.array([1,2,3,134,5])

# %%
np.mean(arr)
# Out:
# np.float64(29.0)

# %%
np.sum(arr)
# Out:
# np.int64(145)

# %%
np.corrcoef(arr1, arr2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 np.corrcoef(arr1, arr2)
#
# NameError: name 'arr1' is not defined
