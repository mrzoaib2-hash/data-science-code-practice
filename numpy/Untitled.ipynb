# %%
import numpy as np
arr=np.array([[1,2,3],
              [3,4,5],
              [5,6,7]])

# %%
print(arr)
# Out:
# [[1 2 3]
#  [3 4 5]
#  [5 6 7]]

# %%
np.sum(arr,axis=0)
# Out:
# array([ 9, 12, 15])

# %%
arr[0:2,1:3]
# Out:
# array([[2, 3],
#        [4, 5]])

# %%
arr3=np.array([[[1,2,3],[3,5,6]],
     [[3,4,5],[6,4,3]]])

# %%
print(arr3[0,1,2])
# Out:
# 6

# %%
print(arr3[:,0,:])
# Out:
# [[1 2 3]
#  [3 4 5]]
