# %%
import numpy as np

# %%
 arr2=np.array([[1,2,3],[2,3,4],[5,6,7],[4,6,4]])

# %%
flat=arr2.flatten()

# %%
flat
# Out:
# array([1, 2, 3, 2, 3, 4, 5, 6, 7, 4, 6, 4])

# %%
flat[3]
# Out:
# np.int64(2)

# %%
flat[3:6]
# Out:
# array([2, 3, 4])

# %%
flat
# Out:
# array([1, 2, 3, 2, 3, 4, 5, 6, 7, 4, 6, 4])

# %%
b=flat[2:7].copy()

# %%
b[0]=444

# %%
flat
# Out:
# array([  1,   2, 444,   2,   3,   4,   5,   6,   7,   4,   6,   4])

# %%
b
# Out:
# array([444,   2,   3,   4,   5])

# %%
arr=np.array([1,2,3,4,5,6,79,33,55,34,56])

# %%
arr[arr>3]
# Out:
# array([ 4,  5,  6, 79, 33, 55, 34, 56])

# %%
matrix=np.array([[1,2,3],[2,3,4],[3,4,5]])

# %%
matrix
# Out:
# array([[1, 2, 3],
#        [2, 3, 4],
#        [3, 4, 5]])

# %%
matrix.shape
# Out:
# (3, 3)

# %%
np.arange(1,6,2)
# Out:
# array([1, 3, 5])

# %%
r=matrix.reshape((3,3))

# %%
matrix[matrix>3]
# Out:
# array([4, 4, 5])
